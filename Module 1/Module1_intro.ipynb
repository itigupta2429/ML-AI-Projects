# %%
Bob=1

# %% [markdown]
# ## check the variable that are in the current environment

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# Bob        int     1
# bob        int     1

# %%
name="iti"
age=35
is_admin=False

# %%
print(name+age)

# %%
type(Bob)
# Out:
# int

# %% [markdown]
# ## i) Strings

# %%
x="hello"
print(x)
# Out:
# hello

# %%
type(x)
# Out:
# str

# %% [markdown]
# ## ii) Lists

# %%
mylist=[1,"2",3.2356,4,5]

# %%
print(mylist)
# Out:
# [1, '2', 3.2356, 4, 5]

# %%
mylist[1:3] #starting from 1 index till 2; do not include 3
# Out:
# ['2', 3.2356]

# %%
mylist[2]="pi" ##strings are mutable

# %%
mylist
# Out:
# [1, '2', 'pi', 4, 5]

# %%
##remove by value
mylist.remove(1)
print(mylist)
# Out:
# ['2', 3.2356, 4, 5]

# %%
##remove by index
mylist.pop(1)
print(mylist)
# Out:
# ['2', 4, 5]

# %%
len(mylist)
# Out:
# 3

# %% [markdown]
# ## iii) Tuples

# %%
mytuples=(2,"john",3.5678,8,"f")

# %%
mytuples[1:3]
# Out:
# ('john', 3.5678)

# %%
##mytuples[2]=2 ##Tuples are immutable

# %% [markdown]
# Sets are like tuples but it does not allow duplicates

# %% [markdown]
# ## iv) Dictionary

# %%
dt = {}
dt["A"]="all people"
dt["2"]="number 2"

# %%
dt
# Out:
# {'A': 'all people', '2': 'number 2'}

# %%
dt.keys()
# Out:
# dict_keys(['A', '2'])

# %%
dict1={"h":["hello","hi"], "w":"world"}
dict1
# Out:
# {'h': ['hello', 'hi'], 'w': 'world'}

# %%
print(dict1["h"])
# Out:
# ['hello', 'hi']

# %%
dict1={"h":["hello","hi"], 
       "w":"world",
      "z":{"another": ["dictionary","wohoo!"]}}
dict1.keys()
# Out:
# dict_keys(['h', 'w', 'z'])

# %%
dict1.values()
# Out:
# dict_values([['hello', 'hi'], 'world', {'another': ['dictionary', 'wohoo!']}])

# %%
dict1["h"][1] 
## instaed of h cannot be indexed by position because in dictionaary it is just the keys and they dont have specific position like lists
# Out:
# 'wohoo!'

# %%
 dict1["z"]["another"][1]

# %%
del dict1["h"]
dict1
# Out:
# {'w': 'world', 'z': {'another': ['dictionary', 'wohoo!']}}

# %%
###delete the dictionary
del dict1

# %%
##updating the dictionary
dict1["k"]="Kite"
dict1
# Out:
# {'w': 'world', 'z': {'another': ['dictionary', 'wohoo!']}, 'k': 'Kite'}

# %% [markdown]
# ## Operators

# %%
sum=1+2
print(sum)
# Out:
# 3

# %%
div=4/2
print(div)
# Out:
# 2.0

# %%
x=0
x += 2 ##Shortcut to add and assign; Addition assignment operator
print(x)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:d75bc268-cd84-400b-9097-cb46ac13e983.png)

# %% [markdown]
# ![image.png](attachment:75e9c590-9784-4f3f-8321-e511c739722d.png)

# %%
a=c=10
b=2

# %%
a == c
# Out:
# True

# %% [markdown]
# ![image.png](attachment:48b9927b-11be-4842-8d72-7e0ccda5d9d2.png)

# %%
a > b  and a==c and a>100
# Out:
# False

# %%
a > b  or a==c or a>100
# Out:
# True

# %% [markdown]
# ![image.png](attachment:b97bbb6b-585d-46a4-919b-b206d7e4f483.png)

# %%
ls=[12,10,"hello"]

# %%
b not in ls
# Out:
# True

# %% [markdown]
# ![image.png](attachment:c1d849d0-35cb-42ae-8a26-8987d4d6bf14.png)

# %% [markdown]
# ## Use identity operators to compare the digital identity (address)

# %%
a=1
b=2
id(a) == id(b)
# Out:
# False

# %%
str="Machine Learning is Awesome" ## Like tuples strings are also immutable

# %%
str[1:3]
# Out:
# 'ac'

# %%
str + str
# Out:
# 'Machine Learning is AwesomeMachine Learning is Awesome'

# %%
(str + " ") *3
# Out:
# 'Machine Learning is Awesome Machine Learning is Awesome Machine Learning is Awesome '

# %% [markdown]
# ## Escape characters

# %%
print('lisa\'s book')
# Out:
# lisa's book

# %% [markdown]
# ## Formatting chaaracters

# %%
name='Robo'
age=10
print("Hi I'm %s and I'm %u years old!" %(name,age))
# Out:
# Hi I'm Robo and I'm 10 years old!

# %% [markdown]
# ## Built-in methods for strings

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
test=name.upper()
print(test)
# Out:
# ROBO

# %%
name.find("o")
# Out:
# 1
