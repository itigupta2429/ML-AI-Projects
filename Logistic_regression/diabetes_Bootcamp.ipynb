# %%
##Steps
#read data from CSV
#Split data into training and testing sets
#Build and train the model using the training data
#Test the trained model using the test set
#Compare the predicted output with the actual output

# %%
import pandas as pd

# %%
diabetes_data=pd.read_csv("diabetes.csv")

# %%
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X=diabetes_data.drop(columns=['Outcome'])
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
Y=diabetes_data['Outcome']
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state=16,max_iter=5000)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=5000, random_state=16)

# %%
print(model.coef_.tolist())
# Out:
# [[0.10196684624482828, 0.035079554240407394, -0.013737934841304816, -0.009638591059755473, -0.0005092906627076015, 0.12373345913835518, 0.7758767999005707, 0.020818867397705946]]

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(Y_test, Y_pred)

# %%
print(accuracy)
# Out:
# 0.7142857142857143

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79        94
#            1       0.70      0.47      0.56        60
#
#     accuracy                           0.71       154
#    macro avg       0.71      0.67      0.67       154
# weighted avg       0.71      0.71      0.70       154
