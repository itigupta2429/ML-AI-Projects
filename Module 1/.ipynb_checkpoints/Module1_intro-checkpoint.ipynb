# %%
Bob=1

# %% [markdown]
# ## check the variable that are in the current environment

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# Bob        int     1
# bob        int     1

# %%
name="iti"
age=35
is_admin=False

# %%
print(name+age)

# %%
type(Bob)
# Out:
# int

# %% [markdown]
# ## i) Strings

# %%
x="hello"
print(x)
# Out:
# hello

# %%
type(x)
# Out:
# str

# %% [markdown]
# ## ii) Lists

# %%
mylist=[1,"2",3.2356,4,5]

# %%
print(mylist)
# Out:
# [1, '2', 3.2356, 4, 5]

# %%
mylist[1:3] #starting from 1 index till 2; do not include 3
# Out:
# ['2', 3.2356]

# %%
mylist[2]="pi" ##strings are mutable

# %%
mylist
# Out:
# [1, '2', 'pi', 4, 5]

# %% [markdown]
# ## iii) Tuples

# %%
mytuples=(2,"john",3.5678,8,"f")

# %%
mytuples[1:3]
# Out:
# ('john', 3.5678)

# %%
##mytuples[2]=2 ##Tuples are immutable

# %% [markdown]
# ## iv) Dictionary

# %%
dt = {}
dt["A"]="all people"
dt["2"]="number 2"

# %%
dt
# Out:
# {'A': 'all people', '2': 'number 2'}

# %%
dt.keys()
# Out:
# dict_keys(['A', '2'])

# %% [markdown]
# ## Operators

# %%
sum=1+2
print(sum)
# Out:
# 3

# %%
div=4/2
print(div)
# Out:
# 2.0

# %%
x=0
x += 2 ##Shortcut to add and assign; Addition assignment operator
print(x)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:d75bc268-cd84-400b-9097-cb46ac13e983.png)
